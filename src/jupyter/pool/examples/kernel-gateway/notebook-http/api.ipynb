# %%
# GET /hello/world
print("I'm cell #1")
# Out:
# I'm cell #1

# %%
# GET /hello/world
print("I'm cell #2")
# Out:
# I'm cell #2

# %%
print('ResponseInfo POST /person')
import json
print(json.dumps({
    "headers" : {
        "Content-Type" : "application/json"
    },
    "status" : 201
}))
# Out:
# ResponseInfo POST /person
# {"headers": {"Content-Type": "application/json"}, "status": 201}

# %%
# GET /person
import json
print(json.dumps({
    "headers" : {
        "Content-Type" : "application/json"
    },
    "status" : 201
}))
# Out:
# {"headers": {"Content-Type": "application/json"}, "status": 201}

# %%
# GET /hello/:firstName/:lastName
import json
req = json.loads(REQUEST)
print(req)
print(req['path'])
print(req['body'])
# print(json.dumps({
#     "headers" : {
#         "Content-Type" : "application/json"
#     },
#     "status" : 201
# }))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ab2f2937092> in <module>
#       1 # GET /hello/:firstName/:lastName
#       2 import json
# ----> 3 req = json.loads(REQUEST)
#       4 print(req)
#       5 print(req['path'])
#
# NameError: name 'REQUEST' is not defined
