# %%
# See https://github.com/matplotlib/jupyter-matplotlib/blob/master/examples/ipympl.ipynb
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib widget
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.figure()
x = [1,2,3]
y = [4,5,6]
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
# plt.figure(1)
plt.plot(np.sin(np.linspace(0, 20, 100)))

# %%
import numpy as np
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
import seaborn as sns
sns.set()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
np.random.seed(342423423)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radii
plt.scatter(x, y, s=area, c=colors, alpha=0.5)

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('pdf')
plt.scatter(np.random.rand(20), np.random.rand(20), c=np.random.rand(20))
