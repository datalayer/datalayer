# %%
# https://jupyter-gmaps.readthedocs.io/en/latest/
import gmaps
gmaps.configure(api_key='AIz...')
gmaps.figure()
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
data = gmaps.datasets.load_dataset('taxi_rides')
gmaps.heatmap(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-bed7b2bea190> in <module>
# ----> 1 data = gmaps.datasets.load_dataset('taxi_rides')
#       2 gmaps.heatmap(data)
#
# AttributeError: module 'gmaps' has no attribute 'datasets'
